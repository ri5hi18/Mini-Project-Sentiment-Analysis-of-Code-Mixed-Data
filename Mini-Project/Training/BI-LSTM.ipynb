# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Bidirectional, LSTM, Dense
from tensorflow.keras.callbacks import EarlyStopping

# Load data from CSV
file_path = 'file.csv'  # Replace with your file path
data = pd.read_csv(file_path)

# Ensure 'commentText' column contains strings
data['commentText'] = data['commentText'].astype(str)

# Function to convert sentiment labels to numerical values
sentiment_dict = {
    'Positive': 0,
    'Negative': 1,
    'Not_relevant': 2,
    'Mixed Feelings': 3,
    'Neutral': 4
}

data['Sentiment_Class'] = data['Sentiment_Class'].map(sentiment_dict)

# Tokenization and sequence padding
max_words = 1000
max_seq_length = 100
tokenizer = Tokenizer(num_words=max_words, oov_token='<OOV>')
tokenizer.fit_on_texts(data['commentText'])

sequences = tokenizer.texts_to_sequences(data['commentText'])
padded_sequences = pad_sequences(sequences, maxlen=max_seq_length, padding='post', truncating='post')

# Prepare target variable
labels = np.asarray(data['Sentiment_Class'])

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(padded_sequences, labels, test_size=0.2, random_state=42)

# Build Bi-LSTM model
model = Sequential()
model.add(Embedding(max_words, 16, input_length=max_seq_length))
model.add(Bidirectional(LSTM(32)))
model.add(Dense(5, activation='softmax'))

model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Training the model
callbacks = [EarlyStopping(monitor='val_loss', patience=3)]

history = model.fit(X_train, y_train, epochs=20, batch_size=64, validation_split=0.2, callbacks=callbacks)

# Evaluate the model on test data
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {accuracy * 100:.2f}%")
# Out:
# Epoch 1/20
# 34/34 [==============================] - 5s 49ms/step - loss: 1.5593 - accuracy: 0.3040 - val_loss: 1.5392 - val_accuracy: 0.3123
# Epoch 2/20
# 34/34 [==============================] - 1s 25ms/step - loss: 1.5124 - accuracy: 0.3106 - val_loss: 1.5076 - val_accuracy: 0.3141
# Epoch 3/20
# 34/34 [==============================] - 1s 24ms/step - loss: 1.4640 - accuracy: 0.3505 - val_loss: 1.4790 - val_accuracy: 0.3569
# Epoch 4/20
# 34/34 [==============================] - 1s 24ms/step - loss: 1.3919 - accuracy: 0.4272 - val_loss: 1.4477 - val_accuracy: 0.3903
# Epoch 5/20
# 34/34 [==============================] - 1s 25ms/step - loss: 1.3127 - accuracy: 0.4565 - val_loss: 1.3720 - val_accuracy: 0.4424
# Epoch 6/20
# 34/34 [==============================] - 1s 25ms/step - loss: 1.2176 - accuracy: 0.5016 - val_loss: 1.3504 - val_accuracy: 0.4164
# Epoch 7/20
# 34/34 [==============================] - 1s 25ms/step - loss: 1.1452 - accuracy: 0.5230 - val_loss: 1.3375 - val_accuracy: 0.4331
# Epoch 8/20
# 34/34 [==============================] - 1s 25ms/step - loss: 1.0846 - accuracy: 0.5583 - val_loss: 1.3611 - val_accuracy: 0.4219
# Epoch 9/20
# 34/34 [==============================] - 1s 25ms/step - loss: 1.0133 - accuracy: 0.5983 - val_loss: 1.3653 - val_accuracy: 0.4517
# Epoch 10/20
# 34/34 [==============================] - 1s 25ms/step - loss: 0.9608 - accuracy: 0.6039 - val_loss: 1.4360 - val_accuracy: 0.4164
# 22/22 [==============================] - 0s 6ms/step - loss: 1.4029 - accuracy: 0.4116
# Test Accuracy: 41.16%

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Bidirectional, LSTM, Dense
from tensorflow.keras.callbacks import EarlyStopping

# Load data from CSV
file_path = 'file.csv'  # Replace with your file path
data = pd.read_csv(file_path)

# Ensure 'commentText' column contains strings
data['commentText'] = data['commentText'].astype(str)

# Function to convert sentiment labels to numerical values
sentiment_dict = {
    'Positive': 0,
    'Negative': 1,
    'Not_relevant': 2,
    'Mixed Feelings': 3,
    'Neutral': 4
}

data['Sentiment_Class'] = data['Sentiment_Class'].map(sentiment_dict)

# Tokenization and sequence padding
max_words = 1000
max_seq_length = 100
tokenizer = Tokenizer(num_words=max_words, oov_token='<OOV>')
tokenizer.fit_on_texts(data['commentText'])

sequences = tokenizer.texts_to_sequences(data['commentText'])
padded_sequences = pad_sequences(sequences, maxlen=max_seq_length, padding='post', truncating='post')

# Prepare target variable
labels = np.asarray(data['Sentiment_Class'])

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(padded_sequences, labels, test_size=0.2, random_state=42)

# Build Bi-LSTM model
model = Sequential()
model.add(Embedding(max_words, 16, input_length=max_seq_length))
model.add(Bidirectional(LSTM(32)))
model.add(Dense(5, activation='softmax'))

model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Training the model
callbacks = [EarlyStopping(monitor='val_loss', patience=3)]

history = model.fit(X_train, y_train, epochs=20, batch_size=64, validation_split=0.2, callbacks=callbacks)

# Evaluate the model on test data
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {accuracy * 100:.2f}%")
# Out:
# Epoch 1/20
# 34/34 [==============================] - 5s 50ms/step - loss: 1.5648 - accuracy: 0.2999 - val_loss: 1.5411 - val_accuracy: 0.3123
# Epoch 2/20
# 34/34 [==============================] - 1s 26ms/step - loss: 1.5151 - accuracy: 0.3101 - val_loss: 1.5132 - val_accuracy: 0.3123
# Epoch 3/20
# 34/34 [==============================] - 1s 25ms/step - loss: 1.4818 - accuracy: 0.3310 - val_loss: 1.4876 - val_accuracy: 0.3420
# Epoch 4/20
# 34/34 [==============================] - 1s 25ms/step - loss: 1.4274 - accuracy: 0.3952 - val_loss: 1.4349 - val_accuracy: 0.3717
# Epoch 5/20
# 34/34 [==============================] - 1s 25ms/step - loss: 1.3128 - accuracy: 0.4491 - val_loss: 1.3811 - val_accuracy: 0.3941
# Epoch 6/20
# 34/34 [==============================] - 1s 25ms/step - loss: 1.2048 - accuracy: 0.4849 - val_loss: 1.3670 - val_accuracy: 0.4294
# Epoch 7/20
# 34/34 [==============================] - 1s 25ms/step - loss: 1.1372 - accuracy: 0.5230 - val_loss: 1.3394 - val_accuracy: 0.4405
# Epoch 8/20
# 34/34 [==============================] - 1s 25ms/step - loss: 1.0626 - accuracy: 0.5542 - val_loss: 1.3677 - val_accuracy: 0.4628
# Epoch 9/20
# 34/34 [==============================] - 1s 25ms/step - loss: 1.0166 - accuracy: 0.5853 - val_loss: 1.3426 - val_accuracy: 0.4610
# Epoch 10/20
# 34/34 [==============================] - 1s 25ms/step - loss: 0.9739 - accuracy: 0.6146 - val_loss: 1.3503 - val_accuracy: 0.4777
# 22/22 [==============================] - 0s 6ms/step - loss: 1.3593 - accuracy: 0.4606
# Test Accuracy: 46.06%
