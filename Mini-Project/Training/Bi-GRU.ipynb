# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Bidirectional, GRU, Dense
from tensorflow.keras.callbacks import EarlyStopping

# Load data from CSV
file_path = 'file.csv'  # Replace with your file path
data = pd.read_csv(file_path)

# Ensure 'commentText' column contains strings
data['commentText'] = data['commentText'].astype(str)

# Function to convert sentiment labels to numerical values
sentiment_dict = {
    'Positive': 0,
    'Negative': 1,
    'Not_relevant': 2,
    'Mixed Feelings': 3,
    'Neutral': 4
}

data['Sentiment_Class'] = data['Sentiment_Class'].map(sentiment_dict)

# Tokenization and sequence padding
max_words = 1000
max_seq_length = 100
tokenizer = Tokenizer(num_words=max_words, oov_token='<OOV>')
tokenizer.fit_on_texts(data['commentText'])

sequences = tokenizer.texts_to_sequences(data['commentText'])
padded_sequences = pad_sequences(sequences, maxlen=max_seq_length, padding='post', truncating='post')

# Prepare target variable
labels = np.asarray(data['Sentiment_Class'])

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(padded_sequences, labels, test_size=0.2, random_state=42)

# Build Bi-GRU model
model = Sequential()
model.add(Embedding(max_words, 16, input_length=max_seq_length))
model.add(Bidirectional(GRU(32)))
model.add(Dense(5, activation='softmax'))

model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Training the model
callbacks = [EarlyStopping(monitor='val_loss', patience=3)]

history = model.fit(X_train, y_train, epochs=20, batch_size=64, validation_split=0.2, callbacks=callbacks)

# Evaluate the model on test data
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {accuracy * 100:.2f}%")
# Out:
# WARNING:tensorflow:From C:\Users\Acer\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From C:\Users\Acer\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\Acer\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/20
# WARNING:tensorflow:From C:\Users\Acer\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\Acer\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 34/34 [==============================] - 5s 51ms/step - loss: 1.5642 - accuracy: 0.3082 - val_loss: 1.5483 - val_accuracy: 0.3123
# Epoch 2/20
# 34/34 [==============================] - 1s 28ms/step - loss: 1.5272 - accuracy: 0.3101 - val_loss: 1.5360 - val_accuracy: 0.3123
# Epoch 3/20
# 34/34 [==============================] - 1s 27ms/step - loss: 1.4972 - accuracy: 0.3212 - val_loss: 1.4962 - val_accuracy: 0.3439
# Epoch 4/20
# 34/34 [==============================] - 1s 28ms/step - loss: 1.4096 - accuracy: 0.4021 - val_loss: 1.4219 - val_accuracy: 0.3922
# Epoch 5/20
# 34/34 [==============================] - 1s 29ms/step - loss: 1.3011 - accuracy: 0.4682 - val_loss: 1.3717 - val_accuracy: 0.4164
# Epoch 6/20
# 34/34 [==============================] - 1s 27ms/step - loss: 1.1820 - accuracy: 0.5132 - val_loss: 1.3336 - val_accuracy: 0.4312
# Epoch 7/20
# 34/34 [==============================] - 1s 27ms/step - loss: 1.0780 - accuracy: 0.5579 - val_loss: 1.3334 - val_accuracy: 0.4461
# Epoch 8/20
# 34/34 [==============================] - 1s 28ms/step - loss: 1.0047 - accuracy: 0.5848 - val_loss: 1.3626 - val_accuracy: 0.4721
# Epoch 9/20
# 34/34 [==============================] - 1s 27ms/step - loss: 0.9418 - accuracy: 0.6151 - val_loss: 1.3528 - val_accuracy: 0.4888
# Epoch 10/20
# 34/34 [==============================] - 1s 28ms/step - loss: 0.8932 - accuracy: 0.6457 - val_loss: 1.4004 - val_accuracy: 0.4777
# 22/22 [==============================] - 0s 7ms/step - loss: 1.3758 - accuracy: 0.4562
# Test Accuracy: 45.62%

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Bidirectional, GRU, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam

# Load data from CSV
file_path = 'file.csv'  # Replace with your file path
data = pd.read_csv(file_path)

# Ensure 'commentText' column contains strings
data['commentText'] = data['commentText'].astype(str)

# Function to convert sentiment labels to numerical values
sentiment_dict = {
    'Positive': 0,
    'Negative': 1,
    'Not_relevant': 2,
    'Mixed Feelings': 3,
    'Neutral': 4
}

data['Sentiment_Class'] = data['Sentiment_Class'].map(sentiment_dict)

# Tokenization and sequence padding
max_words = 5000  # Increase vocabulary size
max_seq_length = 100
tokenizer = Tokenizer(num_words=max_words, oov_token='<OOV>')
tokenizer.fit_on_texts(data['commentText'])

sequences = tokenizer.texts_to_sequences(data['commentText'])
padded_sequences = pad_sequences(sequences, maxlen=max_seq_length, padding='post', truncating='post')

# Prepare target variable
labels = np.asarray(data['Sentiment_Class'])

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(padded_sequences, labels, test_size=0.2, random_state=42)

# Build Bi-GRU model
model = Sequential()
model.add(Embedding(max_words, 64, input_length=max_seq_length))  # Increase embedding dimension
model.add(Bidirectional(GRU(128, return_sequences=True)))  # Return sequences for better representation
model.add(Bidirectional(GRU(64)))
model.add(Dropout(0.5))  # Add dropout for regularization
model.add(Dense(32, activation='relu'))
model.add(Dense(5, activation='softmax'))

optimizer = Adam(learning_rate=1e-4)  # Use a smaller learning rate for better convergence
model.compile(loss='sparse_categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# Training the model
callbacks = [EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)]

history = model.fit(X_train, y_train, epochs=20, batch_size=64, validation_split=0.2, callbacks=callbacks)

# Evaluate the model on test data
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {accuracy * 100:.2f}%")
# Out:
# Epoch 1/20
# 34/34 [==============================] - 12s 173ms/step - loss: 1.6075 - accuracy: 0.2576 - val_loss: 1.5990 - val_accuracy: 0.3123
# Epoch 2/20
# 34/34 [==============================] - 5s 135ms/step - loss: 1.5951 - accuracy: 0.3106 - val_loss: 1.5853 - val_accuracy: 0.3123
# Epoch 3/20
# 34/34 [==============================] - 5s 134ms/step - loss: 1.5821 - accuracy: 0.3101 - val_loss: 1.5703 - val_accuracy: 0.3123
# Epoch 4/20
# 34/34 [==============================] - 4s 130ms/step - loss: 1.5677 - accuracy: 0.3096 - val_loss: 1.5560 - val_accuracy: 0.3123
# Epoch 5/20
# 34/34 [==============================] - 5s 132ms/step - loss: 1.5511 - accuracy: 0.3101 - val_loss: 1.5416 - val_accuracy: 0.3123
# Epoch 6/20
# 34/34 [==============================] - 5s 141ms/step - loss: 1.5387 - accuracy: 0.3115 - val_loss: 1.5325 - val_accuracy: 0.3141
# Epoch 7/20
# 34/34 [==============================] - 4s 130ms/step - loss: 1.5242 - accuracy: 0.3361 - val_loss: 1.5198 - val_accuracy: 0.3253
# Epoch 8/20
# 34/34 [==============================] - 5s 135ms/step - loss: 1.5042 - accuracy: 0.3371 - val_loss: 1.5072 - val_accuracy: 0.3532
# Epoch 9/20
# 34/34 [==============================] - 4s 132ms/step - loss: 1.4811 - accuracy: 0.3654 - val_loss: 1.4817 - val_accuracy: 0.3532
# Epoch 10/20
# 34/34 [==============================] - 5s 134ms/step - loss: 1.4394 - accuracy: 0.3952 - val_loss: 1.4484 - val_accuracy: 0.3680
# Epoch 11/20
# 34/34 [==============================] - 5s 134ms/step - loss: 1.3786 - accuracy: 0.4407 - val_loss: 1.4088 - val_accuracy: 0.4164
# Epoch 12/20
# 34/34 [==============================] - 4s 131ms/step - loss: 1.3164 - accuracy: 0.4695 - val_loss: 1.3828 - val_accuracy: 0.4182
# Epoch 13/20
# 34/34 [==============================] - 5s 134ms/step - loss: 1.2341 - accuracy: 0.5156 - val_loss: 1.3710 - val_accuracy: 0.4294
# Epoch 14/20
# 34/34 [==============================] - 5s 134ms/step - loss: 1.1585 - accuracy: 0.5458 - val_loss: 1.3640 - val_accuracy: 0.4424
# Epoch 15/20
# 34/34 [==============================] - 5s 133ms/step - loss: 1.0689 - accuracy: 0.5718 - val_loss: 1.3869 - val_accuracy: 0.4368
# Epoch 16/20
# 34/34 [==============================] - 5s 137ms/step - loss: 1.0047 - accuracy: 0.6034 - val_loss: 1.4241 - val_accuracy: 0.4387
# Epoch 17/20
# 34/34 [==============================] - 4s 132ms/step - loss: 0.9312 - accuracy: 0.6425 - val_loss: 1.4639 - val_accuracy: 0.4424
# 22/22 [==============================] - 1s 24ms/step - loss: 1.3914 - accuracy: 0.4131
# Test Accuracy: 41.31%
